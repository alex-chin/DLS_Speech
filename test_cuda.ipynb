# %%
#!pip install torch torchvision --index-url https://download.pytorch.org/whl/cu128

# %%
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.4273, 0.1531, 0.2397],
#         [0.9599, 0.1236, 0.6453],
#         [0.5036, 0.7115, 0.8825],
#         [0.0713, 0.4537, 0.5454],
#         [0.7054, 0.9393, 0.7818]])

# %%
import torch
torch.cuda.is_available()
# Out:
# False

# %%
torch.__version__
# Out:
# '2.10.0+cpu'

# %%
import torchaudio

# %%
torchaudio.__version__
# Out:
# '2.10.0+cpu'

# %%
import torchcodec
